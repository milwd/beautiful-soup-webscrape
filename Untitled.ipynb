# %%
# https://www.digikala.com/incredible-offers/

from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import sys
import pandas as pd


try:
    # Fix UTF8 output issues on Windows console.
    # Does nothing if package is not installed
    from win_unicode_console import enable
    enable()
except ImportError:
    pass


originalUrl = "https://www.digikala.com"

url = originalUrl + "/incredible-offers/"  # + str(page)
r = Request(url, headers={'User-Agent':'Mozilla/5.0'})
webpage = urlopen(r).read()
soup = BeautifulSoup(webpage, 'html.parser')

names = []
offs = []
prices = []

for row in soup.findAll('div', attrs={'class':'c-product-list__item js-product-list-content'}):
    # print(row)
    print('+++++++++++++++++++++++++++++++++++++++++++++++++')
    rTitle = row.find('div', attrs={'class':'c-product-box__title js-ab-not-app-incredible-product'})
    r22 = row.find('div', attrs={'class':'c-price__discount-oval'})
    r3 = row.find('div', attrs={'class':'c-price__value-wrapper js-product-card-price'})
    r2 = extractSth(str(r22), 'span')
    #namee = r1.text.replace(" ", "")
    name = str(rTitle.text).replace('\n', '')
    off = str(r2)
    pricee = r3.text.replace(' ', '')
    price = pricee.replace('\n', '')
    names.append(name)
    # names.append(r1.text.replace(' ', ''))
    offs.append(off)
    prices.append(price)
    # print('name : ', r1.text)
    # print('off : ', r2.span)
    # print('price : ', r3.text)
    print('-------------------------------------------------')

print(len(names))
print(len(offs))
print(len(prices))
dic = {'Name':names, 'Price':prices, 'Off':offs}
df = pd.DataFrame(dic)
# df.to_csv('file1.csv', index=False, encoding='utf-8')



# name : c-product-box__title  js-ab-not-app-incredible-product
# price :
# Out:
# C:\Anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'cp1252', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# +++++++++++++++++++++++++++++++++++++++++++++++++
# -------------------------------------------------
# 40
# 40
# 40

# %%
df
# Out:
#                                                  Name           Price  Off
# 0                   گوشی موبایل شیائومی مدل redmi ...  ۳,۹۰۹,۰۰۰تومان   ۵٪
# 1                   ژل آبرسان کامان مدل آلوئه ورا ...     ۳۳,۹۰۰تومان  ۲۶٪
# 2                   بالم لب مرو مدل Mini بسته ۳ عد...     ۱۴,۰۰۰تومان  ۳۳٪
# 3                   مبدل برق هادرون مدل A10E-1    ...     ۳۶,۹۰۰تومان  ۲۰٪
# 4                   مداد شمعی 12 رنگ اریک کراوزه م...     ۱۲,۹۰۰تومان  ۴۸٪
# 5                   کاغذ A4 فولیو پرایم مدل +A بست...     ۶۶,۵۰۰تومان  ۱۹٪
# 6                   ساک لوازم کودک و نوزاد فوروارد...    ۱۶۹,۰۰۰تومان  ۷۴٪
# 7                   اسپری ضد تعریق مردانه پرستیژ م...     ۱۲,۹۰۰تومان  ۱۹٪
# 8                   کتاب پنج قدم فاصله اثر ریچل لی...     ۳۶,۸۰۰تومان  ۳۲٪
# 9                   کتاب اثر مرکب اثر دارن هاردی ا...     ۱۹,۶۰۰تومان  ۸۰٪
# 10                  شارژر همراه رانیک پرایم مدل PB...    ۱۹۹,۰۰۰تومان  ۴۵٪
# 11                  کوله پشتی 65 لیتری فوروارد مدل...    ۳۲۹,۹۰۰تومان  ۶۱٪
# 12                  پوشینه بزرگسال ایزی لایف کد 00...     ۹۷,۹۰۰تومان  ۱۷٪
# 13                  تبلت هوآوی مدل MatePad T10s ظر...  ۳,۸۴۹,۰۰۰تومان   ۸٪
# 14                  صندل مردانه نسیم مدل عارف کد 8...     ۴۵,۰۰۰تومان  ۲۴٪
# 15                  کیف پول چرما اسپرت کد HBK001  ...    ۱۸۳,۰۰۰تومان  ۳۲٪
# 16                  ماسک ضد چروک هیدرودرم مدل Coll...     ۶۹,۰۰۰تومان  ۳۴٪
# 17                  سرویس ملحفه پونته مدل هلیاکد 0...    ۱۰۵,۰۰۰تومان  ۴۵٪
# 18                  روان نویس طرح یونیکورن کد 9911...     ۲۹,۰۰۰تومان  ۲۸٪
# 19                  واکس داشبورد روناکس مدلGm1 حجم...     ۲۲,۸۰۰تومان  ۳۳٪
# 20                  گلیم ماشینی فرش نیروانا کد 613...     ۴۹,۰۰۰تومان  ۴۶٪
# 21                  گلدان ژله ای کد 6-20 مجموعه 9ع...      ۸,۰۰۰تومان  ۲۰٪
# 22                  سرویس خواب ژینورا مدل هانا یکن...    ۱۹۹,۰۰۰تومان  ۵۰٪
# 23                  اس اس دی اینترنال SATA3.0 سیلی...    ۶۹۹,۰۰۰تومان   ۷٪
# 24                  مجموعه نرم افزاری JB Pack 2021...    ۱۰۹,۰۰۰تومان  ۳۹٪
# 25                  کفش پیاده روی مردانه سعیدی مدل...    ۱۷۶,۰۰۰تومان  ۲۰٪
# 26                  سبد نظم دهنده مدل X6          ...     ۴۹,۰۰۰تومان  ۳۲٪
# 27                  ست شیرآلات پادرا مدل بتا کد Wh...  ۱,۳۹۹,۰۰۰تومان  ۳۸٪
# 28                  تیشرت ورزشی زنانه پانیل کد 169...     ۹۳,۰۰۰تومان  ۴۸٪
# 29                  تشک مهمان نایت استار مدل مهر س...    ۲۸۰,۰۰۰تومان  ۱۳٪
# 30                  لامپ ال ای دی 9 وات باوند مدل ...     ۴۷,۸۰۰تومان  ۴۹٪
# 31                  ایرماوس مدل جی30اس            ...    ۲۰۹,۰۰۰تومان  ۱۶٪
# 32                  پیراهن زنانه ناربن مدل 1521411...    ۱۸۸,۰۰۰تومان  ۲۵٪
# 33                  سرپیچ لامپ کد i10             ...     ۵۲,۰۰۰تومان  ۶۰٪
# 34                  ادو پرفیوم زنانه اسکلاره مدل L...     ۵۹,۰۰۰تومان  ۵۱٪
# 35                  دستبند طلا 18عیار مانچو مدل bf...    ۲۸۸,۰۰۰تومان  ۴۰٪
# 36                  ماگ سفری مدل YETI گنجایش 0.800...    ۲۵۹,۰۰۰تومان  ۲۱٪
# 37                  ست تی شرت و شلوارک پسرانه مدل ...    ۱۱۵,۰۰۰تومان  ۲۳٪
# 38                  تیغ یدک سیلور مدل Blaze 5 بسته...    ۱۵۴,۹۰۰تومان  ۴۰٪
# 39                  تبر سفری توماهاوک مدل 0241    ...    ۹۵۰,۰۰۰تومان  ۲۴٪

# %%
def extractSth(txt, sth):
    res1 = txt.find('<'+sth+'>')
    res2 = txt.find('</'+sth+'>')
    if (res1 != -1):
        theIt = txt[res1+len('<'+sth+'>'):res2]
        return theIt
    else:
        return None

# %%
# https://www.digikala.com/incredible-offers/

from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import sys
import pandas as pd


try:
    # Fix UTF8 output issues on Windows console.
    # Does nothing if package is not installed
    from win_unicode_console import enable
    enable()
except ImportError:
    pass


def extractText(txt, sth):
	tagStart = '<'+sth+'>'
	tagEnd = '</'+sth+'>'
	res1 = txt.find(tagStart)
	res2 = txt.find(tagEnd)
	if (res1 != -1):
		theIt = txt[res1+len(tagStart):res2]
		return theIt
	else:
		return None


def replaceMultiple(txt, dic):
	for i, j in dic.items():
		txt = txt.replace(i, j)
	return txt




originalUrl = "https://www.digikala.com"
url = originalUrl + "/incredible-offers/"  # + str(page)
r = Request(url, headers={'User-Agent':'Mozilla/5.0'})
webpage = urlopen(r).read()
soup = BeautifulSoup(webpage, 'html.parser')

names = []
offs = []
prices = []
replaceDict = {'  ':'', '\n':''}

for row in soup.findAll('div', attrs={'class':'c-product-list__item js-product-list-content'}):
	rTitle = row.find('div', attrs={'class':'c-product-box__title js-ab-not-app-incredible-product'})
	rPrice = row.find('div', attrs={'class':'c-price__value-wrapper js-product-card-price'})
	rOff = row.find('div', attrs={'class':'c-price__discount-oval'})
	# name = rTitle.text.replace('\n', '')
	name = replaceMultiple(rTitle.text, replaceDict)
	# price = rPrice.text.replace('\n', '')
	price = replaceMultiple(rPrice.text, replaceDict)
	off = extractText(str(rOff), 'span')
	names.append(name)
	prices.append(price)
	offs.append(off)


print(len(names))
print(len(offs))
print(len(prices))
dic = {'Name':names, 'Price':prices, 'Off':offs}
df = pd.DataFrame(dic)
df.to_csv('file1.csv', index=False, encoding='utf-8')



# name : c-product-box__title js-ab-not-app-incredible-product
# price : c-price__value-wrapper js-product-card-price
# off : c-price__discount-oval : <span>
# Out:
# 40
# 40
# 40

# %%
df
# Out:
#                                                  Name           Price  Off
# 0   گوشی موبایل شیائومی مدل redmi 9T M2010J19SG ظر...  ۳,۹۰۹,۰۰۰تومان   ۵٪
# 1     ژل آبرسان کامان مدل آلوئه ورا حجم 400 میلی لیتر     ۳۳,۹۰۰تومان  ۲۶٪
# 2                   بالم لب مرو مدل Mini بسته ۳ عددی      ۱۴,۰۰۰تومان  ۳۳٪
# 3                          مبدل برق هادرون مدل A10E-1     ۳۶,۹۰۰تومان  ۲۰٪
# 4            مداد شمعی 12 رنگ اریک کراوزه مدل EK33118     ۱۲,۹۰۰تومان  ۴۸٪
# 5            کاغذ A4 فولیو پرایم مدل +A بسته 500 عددی     ۶۶,۵۰۰تومان  ۱۹٪
# 6          ساک لوازم کودک و نوزاد فوروارد کد FCLT3337    ۱۶۹,۰۰۰تومان  ۷۴٪
# 7   اسپری ضد تعریق مردانه پرستیژ مدل Bvlgari حجم 1...     ۱۲,۹۰۰تومان  ۱۹٪
# 8     کتاب پنج قدم فاصله اثر ریچل لیپینکات نشر میلکان     ۳۶,۸۰۰تومان  ۳۲٪
# 9     کتاب اثر مرکب اثر دارن هاردی انتشارات باران خرد     ۱۹,۶۰۰تومان  ۸۰٪
# 10  شارژر همراه رانیک پرایم مدل PB01 ظرفیت 10000 م...    ۱۹۹,۰۰۰تومان  ۴۵٪
# 11           کوله پشتی 65 لیتری فوروارد مدل FCLT402-2    ۳۲۹,۹۰۰تومان  ۶۱٪
# 12  پوشینه بزرگسال ایزی لایف کد 001 سایز کوچک بسته...     ۹۷,۹۰۰تومان  ۱۷٪
# 13  تبلت هوآوی مدل MatePad T10s ظرفیت 32 گیگابایت ...  ۳,۸۴۹,۰۰۰تومان   ۸٪
# 14                  صندل مردانه نسیم مدل عارف کد 8711     ۴۵,۰۰۰تومان  ۲۴٪
# 15                       کیف پول چرما اسپرت کد HBK001    ۱۸۳,۰۰۰تومان  ۳۲٪
# 16   ماسک ضد چروک هیدرودرم مدل Collagen مقدار 100 گرم     ۶۹,۰۰۰تومان  ۳۴٪
# 17     سرویس ملحفه پونته مدل هلیاکد 001 یک نفره 2 تکه    ۱۰۵,۰۰۰تومان  ۴۵٪
# 18                     روان نویس طرح یونیکورن کد 9911     ۲۹,۰۰۰تومان  ۲۸٪
# 19       واکس داشبورد روناکس مدلGm1 حجم ۵۰۰ میلی لیتر     ۲۲,۸۰۰تومان  ۳۳٪
# 20                     گلیم ماشینی فرش نیروانا کد 613     ۴۹,۰۰۰تومان  ۴۶٪
# 21                  گلدان ژله ای کد 6-20 مجموعه 9عددی      ۸,۰۰۰تومان  ۲۰٪
# 22            سرویس خواب ژینورا مدل هانا یکنفره 2 تکه    ۱۹۹,۰۰۰تومان  ۵۰٪
# 23  اس اس دی اینترنال SATA3.0 سیلیکون پاور مدل Ace...    ۶۹۹,۰۰۰تومان   ۷٪
# 24       مجموعه نرم افزاری JB Pack 2021 نشر جی بی تیم    ۱۰۹,۰۰۰تومان  ۳۹٪
# 25             کفش پیاده روی مردانه سعیدی مدل sa 4440    ۱۷۶,۰۰۰تومان  ۲۰٪
# 26                               سبد نظم دهنده مدل X6     ۴۹,۰۰۰تومان  ۳۲٪
# 27                  ست شیرآلات پادرا مدل بتا کد Wh-GL  ۱,۳۹۹,۰۰۰تومان  ۳۸٪
# 28                    تیشرت ورزشی زنانه پانیل کد 169W     ۹۳,۰۰۰تومان  ۴۸٪
# 29  تشک مهمان نایت استار مدل مهر سایز 190*90 سانتی...    ۲۸۰,۰۰۰تومان  ۱۳٪
# 30  لامپ ال ای دی 9 وات باوند مدل A60-3 پایه E27 ب...     ۴۷,۸۰۰تومان  ۴۹٪
# 31                                 ایرماوس مدل جی30اس    ۲۰۹,۰۰۰تومان  ۱۶٪
# 32                  پیراهن زنانه ناربن مدل 1521411-69    ۱۸۸,۰۰۰تومان  ۲۵٪
# 33                                  سرپیچ لامپ کد i10     ۵۲,۰۰۰تومان  ۶۰٪
# 34  ادو پرفیوم زنانه اسکلاره مدل Limbo حجم 55 میلی...     ۵۹,۰۰۰تومان  ۵۱٪
# 35                 دستبند طلا 18عیار مانچو مدل bfg134    ۲۸۸,۰۰۰تومان  ۴۰٪
# 36                ماگ سفری مدل YETI گنجایش 0.800 لیتر    ۲۵۹,۰۰۰تومان  ۲۱٪
# 37    ست تی شرت و شلوارک پسرانه مدل دزد دریایی کد 107    ۱۱۵,۰۰۰تومان  ۲۳٪
# 38              تیغ یدک سیلور مدل Blaze 5 بسته 4 عددی    ۱۵۴,۹۰۰تومان  ۴۰٪
# 39                         تبر سفری توماهاوک مدل 0241    ۹۵۰,۰۰۰تومان  ۲۴٪

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import sys
import pandas as pd


try:
    # Fix UTF8 output issues on Windows console.
    # Does nothing if package is not installed
    from win_unicode_console import enable
    enable()
except:
    pass


def extractText(txt, sth):
	tagStart = '<'+sth+'>'
	tagEnd = '</'+sth+'>'
	res1 = txt.find(tagStart)
	res2 = txt.find(tagEnd)
	if (res1 != -1):
		theIt = txt[res1+len(tagStart):res2]
		return theIt
	else:
		return None


def replaceMultiple(txt, dic):
	for i, j in dic.items():
		txt = txt.replace(i, j)
	return txt



# https://www.digikala.com/incredible-offers/
originalUrl = "https://www.digikala.com"
urlLink = originalUrl + "/incredible-offers/"
# url = urlLink #+ '?pageno=' + str(2)
url = 'https://www.digikala.com/incredible-offers/?pageno=2'
print('Webscraping page : <', urlLink, '> initialized!')
r = Request(url, headers={'User-Agent':'Mozilla/5.0'})
webpage = urlopen(r).read()
print('Sent request and received response!')
soup = BeautifulSoup(webpage, 'html.parser')

names = []
offs = []
prices = []
replaceDict = {'  ':'', '\n':''}
itemCount = 0

for row in soup.findAll('div', attrs={'class':'c-product-list__item js-product-list-content'}):
	itemCount += 1
	print('item : ', itemCount)
	rTitle = row.find('div', attrs={'class':'c-product-box__title js-ab-not-app-incredible-product'})
	rPrice = row.find('div', attrs={'class':'c-price__value-wrapper js-product-card-price'})
	rOff = row.find('div', attrs={'class':'c-price__discount-oval'})
	name = replaceMultiple(rTitle.text, replaceDict)
	print(name)
	price = replaceMultiple(rPrice.text, replaceDict)
	off = extractText(str(rOff), 'span')
	names.append(name)
	prices.append(price)
	offs.append(off)


print(len(names))
print(len(offs))
print(len(prices))
dic = {'Name':names, 'Price':prices, 'Off':offs}
df = pd.DataFrame(dic)
df.to_csv('file1.csv', index=False, encoding='utf-8')

# name : c-product-box__title js-ab-not-app-incredible-product
# price : c-price__value-wrapper js-product-card-price
# off : c-price__discount-oval : <span>
# Out:
# Webscraping page : < https://www.digikala.com/incredible-offers/ > initialized!
# Sent request and received response!
# item :  1
# ادو پرفیوم مردانه اسکلاره مدل Warrior حجم 85 میلی لیتر
# item :  2
# ست جا ادویه ۶ پارچه نورینو طرح Heart
# item :  3
# پولوشرت پسرانه جیبیجو مدل 9926-7
# item :  4
# گردنبند طلا 18 عیار زنانه مایا ماهک مدل MM0941
# item :  5
# جاروبرقی کوپکس مدل VCC-3900
# item :  6
# چهار چرخه کودک طرح زرافه مدل GoandGrown
# item :  7
# کیف ابزار فوروارد مدل FCLT3060
# item :  8
# شارژر بی سیم انرجایزر مدل WCP 117
# item :  9
# دفتر 60 برگ طرح عکاسی مدل 002
# item :  10
# کفش پسرانه مدل پانا رنگ سرمه ای
# item :  11
# تی شرت زنانه کد 120
# item :  12
# پیراهن آستین بلند مردانه مدل 400007 رنگ سبز لجنی
# item :  13
# صندل زنانه مدل ملیکا کد A132
# item :  14
# جوراب مردانه مدل نویدکد A211 مجموعه 6 عددی
# item :  15
# سرویس پخت و پز 21 پارچه عروس مدل ویکتوریا کد 25
# item :  16
# چاقو آشپزخانه وینر مدل T.04
# item :  17
# کیف رودوشی گوگانا کد 300301
# item :  18
# ساک پیک نیک گوگانا مدل 20022
# item :  19
# ست تاپ و شلوارک ورزشی مردانه پانیل کد 14011Y
# item :  20
# تی شرت مردانه اسپیور مدل 2M05-5
# item :  21
# کیف اداری چرم ما مدل Ma-1
# item :  22
# ساعت مچی عقربه ای تن بیتس مدل BF130209
# item :  23
# هدفون بلوتوثی پاناسونیک مدل RP-NJ300B
# item :  24
# زودپز دوقلو ماتریکس کد GMT10
# item :  25
# ساختنی مدل  1-2007 BRIX Blocks
# item :  26
# جانماز ترمه طرح شاه عباسی کدSRM90
# item :  27
# کفش روزمره زنانه شیفر مدل 5330C101
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-3bf7bc6bd0c5> in <module>
#      59         name = replaceMultiple(rTitle.text, replaceDict)
#      60         print(name)
# ---> 61         price = replaceMultiple(rPrice.text, replaceDict)
#      62         off = extractText(str(rOff), 'span')
#      63         names.append(name)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df
# Out:
#                                                  Name           Price  Off
# 0   گوشی موبایل شیائومی مدل redmi 9T M2010J19SG ظر...  ۳,۹۰۹,۰۰۰تومان   ۵٪
# 1     ژل آبرسان کامان مدل آلوئه ورا حجم 400 میلی لیتر     ۳۳,۹۰۰تومان  ۲۶٪
# 2                   بالم لب مرو مدل Mini بسته ۳ عددی      ۱۴,۰۰۰تومان  ۳۳٪
# 3                          مبدل برق هادرون مدل A10E-1     ۳۶,۹۰۰تومان  ۲۰٪
# 4            مداد شمعی 12 رنگ اریک کراوزه مدل EK33118     ۱۲,۹۰۰تومان  ۴۸٪
# 5            کاغذ A4 فولیو پرایم مدل +A بسته 500 عددی     ۶۶,۵۰۰تومان  ۱۹٪
# 6          ساک لوازم کودک و نوزاد فوروارد کد FCLT3337    ۱۶۹,۰۰۰تومان  ۷۴٪
# 7   اسپری ضد تعریق مردانه پرستیژ مدل Bvlgari حجم 1...     ۱۲,۹۰۰تومان  ۱۹٪
# 8     کتاب پنج قدم فاصله اثر ریچل لیپینکات نشر میلکان     ۳۶,۸۰۰تومان  ۳۲٪
# 9     کتاب اثر مرکب اثر دارن هاردی انتشارات باران خرد     ۱۹,۶۰۰تومان  ۸۰٪
# 10  شارژر همراه رانیک پرایم مدل PB01 ظرفیت 10000 م...    ۱۹۹,۰۰۰تومان  ۴۵٪
# 11           کوله پشتی 65 لیتری فوروارد مدل FCLT402-2    ۳۲۹,۹۰۰تومان  ۶۱٪
# 12  پوشینه بزرگسال ایزی لایف کد 001 سایز کوچک بسته...     ۹۷,۹۰۰تومان  ۱۷٪
# 13  تبلت هوآوی مدل MatePad T10s ظرفیت 32 گیگابایت ...  ۳,۸۴۹,۰۰۰تومان   ۸٪
# 14                  صندل مردانه نسیم مدل عارف کد 8711     ۴۵,۰۰۰تومان  ۲۴٪
# 15                       کیف پول چرما اسپرت کد HBK001    ۱۸۳,۰۰۰تومان  ۳۲٪
# 16   ماسک ضد چروک هیدرودرم مدل Collagen مقدار 100 گرم     ۶۹,۰۰۰تومان  ۳۴٪
# 17     سرویس ملحفه پونته مدل هلیاکد 001 یک نفره 2 تکه    ۱۰۵,۰۰۰تومان  ۴۵٪
# 18                     روان نویس طرح یونیکورن کد 9911     ۲۹,۰۰۰تومان  ۲۸٪
# 19       واکس داشبورد روناکس مدلGm1 حجم ۵۰۰ میلی لیتر     ۲۲,۸۰۰تومان  ۳۳٪
# 20                     گلیم ماشینی فرش نیروانا کد 613     ۴۹,۰۰۰تومان  ۴۶٪
# 21                  گلدان ژله ای کد 6-20 مجموعه 9عددی      ۸,۰۰۰تومان  ۲۰٪
# 22            سرویس خواب ژینورا مدل هانا یکنفره 2 تکه    ۱۹۹,۰۰۰تومان  ۵۰٪
# 23  اس اس دی اینترنال SATA3.0 سیلیکون پاور مدل Ace...    ۶۹۹,۰۰۰تومان   ۷٪
# 24       مجموعه نرم افزاری JB Pack 2021 نشر جی بی تیم    ۱۰۹,۰۰۰تومان  ۳۹٪
# 25             کفش پیاده روی مردانه سعیدی مدل sa 4440    ۱۷۶,۰۰۰تومان  ۲۰٪
# 26                               سبد نظم دهنده مدل X6     ۴۹,۰۰۰تومان  ۳۲٪
# 27                  ست شیرآلات پادرا مدل بتا کد Wh-GL  ۱,۳۹۹,۰۰۰تومان  ۳۸٪
# 28                    تیشرت ورزشی زنانه پانیل کد 169W     ۹۳,۰۰۰تومان  ۴۸٪
# 29  تشک مهمان نایت استار مدل مهر سایز 190*90 سانتی...    ۲۸۰,۰۰۰تومان  ۱۳٪
# 30  لامپ ال ای دی 9 وات باوند مدل A60-3 پایه E27 ب...     ۴۷,۸۰۰تومان  ۴۹٪
# 31                                 ایرماوس مدل جی30اس    ۲۰۹,۰۰۰تومان  ۱۶٪
# 32                  پیراهن زنانه ناربن مدل 1521411-69    ۱۸۸,۰۰۰تومان  ۲۵٪
# 33                                  سرپیچ لامپ کد i10     ۵۲,۰۰۰تومان  ۶۰٪
# 34  ادو پرفیوم زنانه اسکلاره مدل Limbo حجم 55 میلی...     ۵۹,۰۰۰تومان  ۵۱٪
# 35                 دستبند طلا 18عیار مانچو مدل bfg134    ۲۸۸,۰۰۰تومان  ۴۰٪
# 36                ماگ سفری مدل YETI گنجایش 0.800 لیتر    ۲۵۹,۰۰۰تومان  ۲۱٪
# 37    ست تی شرت و شلوارک پسرانه مدل دزد دریایی کد 107    ۱۱۵,۰۰۰تومان  ۲۳٪
# 38              تیغ یدک سیلور مدل Blaze 5 بسته 4 عددی    ۱۵۴,۹۰۰تومان  ۴۰٪
# 39                         تبر سفری توماهاوک مدل 0241    ۹۵۰,۰۰۰تومان  ۲۴٪

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import sys
import pandas as pd


try:
    # Fix UTF8 output issues on Windows console.
    # Does nothing if package is not installed
    from win_unicode_console import enable
    enable()
except:
    pass


def extractText(txt, sth):
	tagStart = '<'+sth+'>'
	tagEnd = '</'+sth+'>'
	res1 = txt.find(tagStart)
	res2 = txt.find(tagEnd)
	if (res1 != -1):
		theIt = txt[res1+len(tagStart):res2]
		return theIt
	else:
		return None


def replaceMultiple(txt, dic):
	for i, j in dic.items():
		txt = txt.replace(i, j)
	return txt


def checkActive(r):
	if r != None:
		return r.text
	else:
		return str(None)


# https://www.digikala.com/incredible-offers/
originalUrl = "https://www.digikala.com"
urlLink = originalUrl + "/incredible-offers/"
url = urlLink + '?pageno=' + str(2)
print('Webscraping page : <', urlLink, '> initialized!')
r = Request(url, headers={'User-Agent':'Mozilla/5.0'})
webpage = urlopen(r).read()
print('Sent request and received response!')
soup = BeautifulSoup(webpage, 'html.parser')

names = []
offs = []
prices = []
replaceDict = {'  ':'', '\n':''}
itemCount = 0

for row in soup.findAll('div', attrs={'class':'c-product-list__item js-product-list-content'}):
	itemCount += 1
	print('item : ', itemCount)
	rTitle = row.find('div', attrs={'class':'c-product-box__title js-ab-not-app-incredible-product'})
	rPrice = row.find('div', attrs={'class':'c-price__value-wrapper js-product-card-price'})
	rOff = row.find('div', attrs={'class':'c-price__discount-oval'})
	nameOut = checkActive(rTitle)
	name = replaceMultiple(nameOut, replaceDict)
	priceOut = checkActive(rPrice)
	price = replaceMultiple(priceOut, replaceDict)
	off = extractText(str(rOff), 'span')
	names.append(name)
	prices.append(price)
	offs.append(off)


print(len(names))
print(len(offs))
print(len(prices))
dic = {'Name':names, 'Price':prices, 'Off':offs}
df = pd.DataFrame(dic)
# df.to_csv('file1.csv', index=False, encoding='utf-8')

# name : c-product-box__title js-ab-not-app-incredible-product
# price : c-price__value-wrapper js-product-card-price
# off : c-price__discount-oval : <span>
# Out:
# Webscraping page : < https://www.digikala.com/incredible-offers/ > initialized!
# Sent request and received response!
# item :  1
# item :  2
# item :  3
# item :  4
# item :  5
# item :  6
# item :  7
# item :  8
# item :  9
# item :  10
# item :  11
# item :  12
# item :  13
# item :  14
# item :  15
# item :  16
# item :  17
# item :  18
# item :  19
# item :  20
# item :  21
# item :  22
# item :  23
# item :  24
# item :  25
# item :  26
# item :  27
# 27
# 27
# 27

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import sys
import pandas as pd


try:
    # Fix UTF8 output issues on Windows console.
    # Does nothing if package is not installed
    from win_unicode_console import enable
    enable()
except:
    pass


def extractText(txt, sth):
	tagStart = '<'+sth+'>'
	tagEnd = '</'+sth+'>'
	res1 = txt.find(tagStart)
	res2 = txt.find(tagEnd)
	if (res1 != -1):
		theIt = txt[res1+len(tagStart):res2]
		return theIt
	else:
		return None


def replaceMultiple(txt, dic):
	for i, j in dic.items():
		txt = txt.replace(i, j)
	return txt


def checkActive(ro):
	if ro != None:
		return ro.text
	else:
		return str(None)


# https://www.digikala.com/incredible-offers/
originalUrl = "https://www.digikala.com"
urlLink = originalUrl + "/incredible-offers/"

names = []
offs = []
prices = []
replaceDict = {'  ':'', '\n':''}
itemCount = 0
noPages = 3

for i in range(1, noPages):
	url = urlLink + '?pageno=' + str(i)
	print('Webscraping page : <', url, '> initialized!')
	r = Request(url, headers={'User-Agent':'Mozilla/5.0'})
	webpage = urlopen(r).read()
	print('Sent request and received response!')
	soup = BeautifulSoup(webpage, 'html.parser')
	for row in soup.findAll('div', attrs={'class':'c-product-list__item js-product-list-content'}):
		itemCount += 1
		print('item : ', itemCount)
		rTitle = row.find('div', attrs={'class':'c-product-box__title js-ab-not-app-incredible-product'})
		rPrice = row.find('div', attrs={'class':'c-price__value-wrapper js-product-card-price'})
		rOff = row.find('div', attrs={'class':'c-price__discount-oval'})
		nameOut = checkActive(rTitle)
		name = replaceMultiple(nameOut, replaceDict)
		priceOut = checkActive(rPrice)
		price = replaceMultiple(priceOut, replaceDict)
		off = extractText(str(rOff), 'span')
		names.append(name)
		prices.append(price)
		offs.append(off)


print(len(names))
print(len(offs))
print(len(prices))
dic = {'Name':names, 'Price':prices, 'Off':offs}
df = pd.DataFrame(dic)
df.to_csv('file1.csv', index=False, encoding='utf-8')

# name : c-product-box__title js-ab-not-app-incredible-product
# price : c-price__value-wrapper js-product-card-price
# off : c-price__discount-oval : <span>
# Out:
# Webscraping page : < https://www.digikala.com/incredible-offers/?pageno=1 > initialized!
# Sent request and received response!
# item :  1
# item :  2
# item :  3
# item :  4
# item :  5
# item :  6
# item :  7
# item :  8
# item :  9
# item :  10
# item :  11
# item :  12
# item :  13
# item :  14
# item :  15
# item :  16
# item :  17
# item :  18
# item :  19
# item :  20
# item :  21
# item :  22
# item :  23
# item :  24
# item :  25
# item :  26
# item :  27
# item :  28
# item :  29
# item :  30
# item :  31
# item :  32
# item :  33
# item :  34
# item :  35
# item :  36
# item :  37
# item :  38
# item :  39
# item :  40
# Webscraping page : < https://www.digikala.com/incredible-offers/?pageno=2 > initialized!
# Sent request and received response!
# item :  41
# item :  42
# item :  43
# item :  44
# item :  45
# item :  46
# item :  47
# item :  48
# item :  49
# item :  50
# item :  51
# item :  52
# item :  53
# item :  54
# item :  55
# item :  56
# item :  57
# item :  58
# item :  59
# item :  60
# item :  61
# item :  62
# item :  63
# item :  64
# item :  65
# item :  66
# item :  67
# 67
# 67
# 67

# %%
df
# Out:
#                                                  Name           Price   Off
# 0   گوشی موبایل شیائومی مدل redmi 9T M2010J19SG ظر...  ۳,۹۰۹,۰۰۰تومان    ۵٪
# 1     ژل آبرسان کامان مدل آلوئه ورا حجم 400 میلی لیتر     ۳۳,۹۰۰تومان   ۲۶٪
# 2                   بالم لب مرو مدل Mini بسته ۳ عددی      ۱۴,۰۰۰تومان   ۳۳٪
# 3                          مبدل برق هادرون مدل A10E-1     ۳۶,۹۰۰تومان   ۲۰٪
# 4            مداد شمعی 12 رنگ اریک کراوزه مدل EK33118     ۱۲,۹۰۰تومان   ۴۸٪
# ..                                                ...             ...   ...
# 62              هدفون بلوتوثی پاناسونیک مدل RP-NJ300B    ۴۹۹,۰۰۰تومان   ۴۰٪
# 63                       زودپز دوقلو ماتریکس کد GMT10  ۲,۹۰۰,۰۰۰تومان   ۵۸٪
# 64                     ساختنی مدل  1-2007 BRIX Blocks     ۷۱,۵۰۰تومان   ۴۰٪
# 65                  جانماز ترمه طرح شاه عباسی کدSRM90     ۲۵,۵۰۰تومان   ۲۰٪
# 66                 کفش روزمره زنانه شیفر مدل 5330C101            None  None
#
# [67 rows x 3 columns]

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import sys
import pandas as pd
try:
    # Fix UTF8 output issues on Windows console.
    from win_unicode_console import enable
    enable()
except:
    pass


def extractText(txt, sth):
	tagStart = '<'+sth+'>'
	tagEnd = '</'+sth+'>'
	res1 = txt.find(tagStart)
	res2 = txt.find(tagEnd)
	if (res1 != -1):
		theIt = txt[res1+len(tagStart):res2]
		return theIt
	else:
		return None


def replaceMultiple(txt, dic):
	for i, j in dic.items():
		txt = txt.replace(i, j)
	return txt


def checkActive(ro):
	if ro != None:
		return ro.text
	else:
		return str(None)


# https://www.digikala.com/incredible-offers/
originalUrl = "https://www.digikala.com"
urlLink = originalUrl + "/incredible-offers/"

names = []
offs = []
prices = []
replaceDict = {'  ':'', '\n':''}
itemCount = 0
noPages = 3

for i in range(1, noPages):
	url = urlLink + '?pageno=' + str(i)
	print('\nWebscraping page : <', url, '>')
	r = Request(url, headers={'User-Agent':'Mozilla/5.0'})
	print('request sent ...')
	webpage = urlopen(r).read()
	print('response received!')
	soup = BeautifulSoup(webpage, 'html.parser')
	print('page parsing initialized ...')
	for row in soup.findAll('div', attrs={'class':'c-product-list__item js-product-list-content'}):
		itemCount += 1
		rTitle = row.find('div', attrs={'class':'c-product-box__title js-ab-not-app-incredible-product'})
		rPrice = row.find('div', attrs={'class':'c-price__value-wrapper js-product-card-price'})
		rOff = row.find('div', attrs={'class':'c-price__discount-oval'})
		nameOut = checkActive(rTitle)
		name = replaceMultiple(nameOut, replaceDict)
		priceOut = checkActive(rPrice)
		price = replaceMultiple(priceOut, replaceDict)
		off = extractText(str(rOff), 'span')
		names.append(name)
		prices.append(price)
		offs.append(off)
	print('page', i, 'done!')


print(itemCount, ' items read totally!')
dic = {'Name':names, 'Price':prices, 'Off':offs}
df = pd.DataFrame(dic)
df.to_csv('file1.csv', index=False, encoding='utf-8')

# name : c-product-box__title js-ab-not-app-incredible-product
# price : c-price__value-wrapper js-product-card-price
# off : c-price__discount-oval : <span>
# Out:
# C:\Anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'cp1252', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)
# Webscraping page : < https://www.digikala.com/incredible-offers/?pageno=1 >
# request sent ...
# response received!
# page parsing initialized ...
# page 1 done!
#
# Webscraping page : < https://www.digikala.com/incredible-offers/?pageno=2 >
# request sent ...
# response received!
# page parsing initialized ...
# page 2 done!
# 67  items read totally!

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd


def extractText(txt, sth):
	tagStart = '<'+sth+'>'
	tagEnd = '</'+sth+'>'
	res1 = txt.find(tagStart)
	res2 = txt.find(tagEnd)
	if (res1 != -1):
		theIt = txt[res1+len(tagStart):res2]
		return theIt
	else:
		return None


def replaceMultiple(txt, dic):
	for i, j in dic.items():
		txt = txt.replace(i, j)
	return txt


def checkActive(ro):
	if ro != None:
		return ro.text
	else:
		return None


def result(inp):
	global replaceDict
	out1 = checkActive(inp)
	if out1:
		return replaceMultiple(out1, replaceDict)
	else:
		return 'not available'


# https://www.digikala.com/incredible-offers/
originalUrl = "https://www.digikala.com"
urlLink = originalUrl + "/incredible-offers/"

names = []
offs = []
prices = []
noPages = 3
itemCount = 0

replaceDict = {'  ':'', '\n':''}


for i in range(1, noPages):

	url = urlLink + '?pageno=' + str(i)

	r = Request(url, headers={'User-Agent':'Mozilla/5.0'})
	webpage = urlopen(r).read()
	soup = BeautifulSoup(webpage, 'html.parser')
	
	for row in soup.findAll('div', attrs={'class':'c-product-list__item js-product-list-content'}):
		itemCount += 1
		rName = row.find('div', attrs={'class':'c-product-box__title js-ab-not-app-incredible-product'})
		rPrice = row.find('div', attrs={'class':'c-price__value-wrapper js-product-card-price'})
		rOff = row.find('div', attrs={'class':'c-price__discount-oval'})

		name = result(rName)
		price = result(rPrice)
		off = extractText(str(rOff), 'span')
		names.append(name)
		prices.append(price)
		offs.append(off)
	
	print('page', i, 'done!')

print(itemCount, ' items read totally!')

dic = {'Name':names, 'Price':prices, 'Off':offs}
df = pd.DataFrame(dic)

# df.to_csv('file1.csv', index=False, encoding='utf-8')

# df.to_html('file2.html')

# name : c-product-box__title js-ab-not-app-incredible-product
# price : c-price__value-wrapper js-product-card-price
# off : c-price__discount-oval : <span>
# Out:
# page 1 done!
# page 2 done!
# 66  items read totally!

# %%
df
# Out:
#                                                  Name           Price   Off
# 0   گوشی موبایل شیائومی مدل redmi 9T M2010J19SG ظر...  ۳,۹۰۹,۰۰۰تومان    ۵٪
# 1     ژل آبرسان کامان مدل آلوئه ورا حجم 400 میلی لیتر     ۳۳,۹۰۰تومان   ۲۶٪
# 2                   بالم لب مرو مدل Mini بسته ۳ عددی      ۱۴,۰۰۰تومان   ۳۳٪
# 3                          مبدل برق هادرون مدل A10E-1     ۳۶,۹۰۰تومان   ۲۰٪
# 4            مداد شمعی 12 رنگ اریک کراوزه مدل EK33118     ۱۲,۹۰۰تومان   ۴۸٪
# ..                                                ...             ...   ...
# 61                          کیف اداری چرم ما مدل Ma-1    ۶۳۰,۰۰۰تومان   ۳۶٪
# 62                     ساختنی مدل  1-2007 BRIX Blocks     ۷۱,۵۰۰تومان   ۴۰٪
# 63                        کیف رودوشی گوگانا کد 300301   not available  None
# 64                  جانماز ترمه طرح شاه عباسی کدSRM90   not available  None
# 65                 کفش روزمره زنانه شیفر مدل 5330C101   not available  None
#
# [66 rows x 3 columns]
